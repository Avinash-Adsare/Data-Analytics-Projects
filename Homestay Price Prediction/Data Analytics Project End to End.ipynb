# %% [markdown]
# # Project Objective : Building an Regression model to predict the Homestay prices of Residential Properties

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import matplotlib.pyplot as plt
import matplotlib.style

# %% [markdown]
# ## Importing The Data

# %%
df = pd.read_excel('/content/sample_data/Air_BNB.xlsx')

# %%
df.drop('id',axis=1,inplace=True)

# %%
df
# Out:
#              room_type  accommodates  bathrooms cancellation_policy  \
# 0      Entire home/apt           3.0        1.0              strict
# 1      Entire home/apt           7.0        1.0              strict
# 2      Entire home/apt           5.0        1.0            moderate
# 3      Entire home/apt           4.0        1.0            flexible
# 4      Entire home/apt           2.0        1.0            moderate
# ...                ...           ...        ...                 ...
# 74106     Private room           1.0        1.0            flexible
# 74107  Entire home/apt           4.0        2.0            moderate
# 74108  Entire home/apt           5.0        1.0            moderate
# 74109  Entire home/apt           2.0        1.0              strict
# 74110  Entire home/apt           4.0        1.0            moderate
#
#        cleaning_fee instant_bookable  review_scores_rating  bedrooms  beds  \
# 0               1.0                f                 100.0       1.0   1.0
# 1               1.0                t                  93.0       3.0   3.0
# 2               1.0                t                  92.0       1.0   3.0
# 3               1.0                f                   NaN       2.0   2.0
# 4               1.0                t                  40.0       0.0   1.0
# ...             ...              ...                   ...       ...   ...
# 74106           0.0                f                   NaN       1.0   1.0
# 74107           1.0                f                  93.0       2.0   4.0
# 74108           1.0                t                  94.0       2.0   2.0
# 74109           1.0                t                   NaN       0.0   2.0
# 74110           0.0                f                  96.0       1.0   2.0
#
#        log_price
# 0       5.010635
# 1       5.129899
# 2       4.976734
# 3       6.620073
# 4       4.744932
# ...          ...
# 74106   4.605170
# 74107   5.043425
# 74108   5.220356
# 74109   5.273000
# 74110   4.852030
#
# [74111 rows x 10 columns]

# %%
print("The number of colums is",df.shape[1])
print("The number of rows is",df.shape[0])
# Out:
# The number of colums is 10
# The number of rows is 74111

# %%
df.head()
# Out:
#          room_type  accommodates  bathrooms cancellation_policy  cleaning_fee  \
# 0  Entire home/apt           3.0        1.0              strict           1.0
# 1  Entire home/apt           7.0        1.0              strict           1.0
# 2  Entire home/apt           5.0        1.0            moderate           1.0
# 3  Entire home/apt           4.0        1.0            flexible           1.0
# 4  Entire home/apt           2.0        1.0            moderate           1.0
#
#   instant_bookable  review_scores_rating  bedrooms  beds  log_price
# 0                f                 100.0       1.0   1.0   5.010635
# 1                t                  93.0       3.0   3.0   5.129899
# 2                t                  92.0       1.0   3.0   4.976734
# 3                f                   NaN       2.0   2.0   6.620073
# 4                t                  40.0       0.0   1.0   4.744932

# %%
df.tail(10)
# Out:
#              room_type  accommodates  bathrooms cancellation_policy  \
# 74101     Private room           1.0        1.0            moderate
# 74102      Shared room          10.0        3.0            flexible
# 74103  Entire home/apt           2.0        1.0            moderate
# 74104  Entire home/apt           2.0        1.0              strict
# 74105     Private room           2.0        1.0            moderate
# 74106     Private room           1.0        1.0            flexible
# 74107  Entire home/apt           4.0        2.0            moderate
# 74108  Entire home/apt           5.0        1.0            moderate
# 74109  Entire home/apt           2.0        1.0              strict
# 74110  Entire home/apt           4.0        1.0            moderate
#
#        cleaning_fee instant_bookable  review_scores_rating  bedrooms  beds  \
# 74101           1.0                f                  90.0       1.0   1.0
# 74102           0.0                f                  80.0       1.0  10.0
# 74103           1.0                f                  98.0       1.0   1.0
# 74104           1.0                f                 100.0       1.0   1.0
# 74105           1.0                f                  91.0       1.0   1.0
# 74106           0.0                f                   NaN       1.0   1.0
# 74107           1.0                f                  93.0       2.0   4.0
# 74108           1.0                t                  94.0       2.0   2.0
# 74109           1.0                t                   NaN       0.0   2.0
# 74110           0.0                f                  96.0       1.0   2.0
#
#        log_price
# 74101   4.584967
# 74102   4.110874
# 74103   5.135798
# 74104   4.356709
# 74105   4.248495
# 74106   4.605170
# 74107   5.043425
# 74108   5.220356
# 74109   5.273000
# 74110   4.852030

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74111 entries, 0 to 74110
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   room_type             74106 non-null  object
#  1   accommodates          74108 non-null  float64
#  2   bathrooms             73908 non-null  float64
#  3   cancellation_policy   74103 non-null  object
#  4   cleaning_fee          74107 non-null  float64
#  5   instant_bookable      74111 non-null  object
#  6   review_scores_rating  57389 non-null  float64
#  7   bedrooms              74019 non-null  float64
#  8   beds                  73980 non-null  float64
#  9   log_price             74111 non-null  float64
# dtypes: float64(7), object(3)
# memory usage: 5.7+ MB

# %%
round(df.describe(include='all'),2).T
# Out:
#                         count unique              top   freq   mean   std  \
# room_type               74106      3  Entire home/apt  41308    NaN   NaN
# accommodates          74108.0    NaN              NaN    NaN   3.16  2.15
# bathrooms             73908.0    NaN              NaN    NaN   1.24  0.58
# cancellation_policy     74103      3           strict  32500    NaN   NaN
# cleaning_fee          74107.0    NaN              NaN    NaN   0.73  0.44
# instant_bookable        74111      2                f  54660    NaN   NaN
# review_scores_rating  57389.0    NaN              NaN    NaN  94.07  7.84
# bedrooms              74019.0    NaN              NaN    NaN   1.27  0.85
# beds                  73980.0    NaN              NaN    NaN   1.71  1.25
# log_price             74111.0    NaN              NaN    NaN   4.78  0.72
#
#                        min   25%   50%    75%    max
# room_type              NaN   NaN   NaN    NaN    NaN
# accommodates           1.0   2.0   2.0    4.0   16.0
# bathrooms              0.0   1.0   1.0    1.0    8.0
# cancellation_policy    NaN   NaN   NaN    NaN    NaN
# cleaning_fee           0.0   0.0   1.0    1.0    1.0
# instant_bookable       NaN   NaN   NaN    NaN    NaN
# review_scores_rating  20.0  92.0  96.0  100.0  100.0
# bedrooms               0.0   1.0   1.0    1.0   10.0
# beds                   0.0   1.0   1.0    2.0   18.0
# log_price              0.0  4.32  4.71   5.22    7.6

# %%
df['room_type'].nunique()
# Out:
# 3

# %%
for column in df.columns:
    if df[column].dtype == 'object':
        print(column.upper(),':', df['room_type'].nunique())
        print()
        print(df[column].value_counts())
        print()
# Out:
# ROOM_TYPE : 3
#
# room_type
# Entire home/apt    41308
# Private room       30635
# Shared room         2163
# Name: count, dtype: int64
#
# CANCELLATION_POLICY : 3
#
# cancellation_policy
# strict      32500
# flexible    22543
# moderate    19060
# Name: count, dtype: int64
#
# INSTANT_BOOKABLE : 3
#
# instant_bookable
# f    54660
# t    19451
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['room_type', 'accommodates', 'bathrooms', 'cancellation_policy',
#        'cleaning_fee', 'instant_bookable', 'review_scores_rating', 'bedrooms',
#        'beds', 'log_price'],
#       dtype='object')

# %%
df_2 = df.copy()

# %%
df_2.drop_duplicates(inplace=True)

# %%
df_2
# Out:
#              room_type  accommodates  bathrooms cancellation_policy  \
# 0      Entire home/apt           3.0        1.0              strict
# 1      Entire home/apt           7.0        1.0              strict
# 2      Entire home/apt           5.0        1.0            moderate
# 3      Entire home/apt           4.0        1.0            flexible
# 4      Entire home/apt           2.0        1.0            moderate
# ...                ...           ...        ...                 ...
# 74104  Entire home/apt           2.0        1.0              strict
# 74107  Entire home/apt           4.0        2.0            moderate
# 74108  Entire home/apt           5.0        1.0            moderate
# 74109  Entire home/apt           2.0        1.0              strict
# 74110  Entire home/apt           4.0        1.0            moderate
#
#        cleaning_fee instant_bookable  review_scores_rating  bedrooms  beds  \
# 0               1.0                f                 100.0       1.0   1.0
# 1               1.0                t                  93.0       3.0   3.0
# 2               1.0                t                  92.0       1.0   3.0
# 3               1.0                f                   NaN       2.0   2.0
# 4               1.0                t                  40.0       0.0   1.0
# ...             ...              ...                   ...       ...   ...
# 74104           1.0                f                 100.0       1.0   1.0
# 74107           1.0                f                  93.0       2.0   4.0
# 74108           1.0                t                  94.0       2.0   2.0
# 74109           1.0                t                   NaN       0.0   2.0
# 74110           0.0                f                  96.0       1.0   2.0
#
#        log_price
# 0       5.010635
# 1       5.129899
# 2       4.976734
# 3       6.620073
# 4       4.744932
# ...          ...
# 74104   4.356709
# 74107   5.043425
# 74108   5.220356
# 74109   5.273000
# 74110   4.852030
#
# [54117 rows x 10 columns]

# %%
df_2.isnull().sum()
# Out:
# room_type                   5
# accommodates                3
# bathrooms                 195
# cancellation_policy         8
# cleaning_fee                4
# instant_bookable            0
# review_scores_rating    10215
# bedrooms                   92
# beds                      125
# log_price                   0
# dtype: int64

# %%
df_2
# Out:
#              room_type  accommodates  bathrooms cancellation_policy  \
# 0      Entire home/apt           3.0        1.0              strict
# 1      Entire home/apt           7.0        1.0              strict
# 2      Entire home/apt           5.0        1.0            moderate
# 3      Entire home/apt           4.0        1.0            flexible
# 4      Entire home/apt           2.0        1.0            moderate
# ...                ...           ...        ...                 ...
# 74104  Entire home/apt           2.0        1.0              strict
# 74107  Entire home/apt           4.0        2.0            moderate
# 74108  Entire home/apt           5.0        1.0            moderate
# 74109  Entire home/apt           2.0        1.0              strict
# 74110  Entire home/apt           4.0        1.0            moderate
#
#        cleaning_fee instant_bookable  review_scores_rating  bedrooms  beds  \
# 0               1.0                f                 100.0       1.0   1.0
# 1               1.0                t                  93.0       3.0   3.0
# 2               1.0                t                  92.0       1.0   3.0
# 3               1.0                f                   NaN       2.0   2.0
# 4               1.0                t                  40.0       0.0   1.0
# ...             ...              ...                   ...       ...   ...
# 74104           1.0                f                 100.0       1.0   1.0
# 74107           1.0                f                  93.0       2.0   4.0
# 74108           1.0                t                  94.0       2.0   2.0
# 74109           1.0                t                   NaN       0.0   2.0
# 74110           0.0                f                  96.0       1.0   2.0
#
#        log_price
# 0       5.010635
# 1       5.129899
# 2       4.976734
# 3       6.620073
# 4       4.744932
# ...          ...
# 74104   4.356709
# 74107   5.043425
# 74108   5.220356
# 74109   5.273000
# 74110   4.852030
#
# [54117 rows x 10 columns]

# %%
df_2 = pd.get_dummies(df_2,columns = ['room_type','cancellation_policy','instant_bookable'],drop_first = True,dtype = float)

# %%
df_2
# Out:
#        accommodates  bathrooms  cleaning_fee  review_scores_rating  bedrooms  \
# 0               3.0        1.0           1.0                 100.0       1.0
# 1               7.0        1.0           1.0                  93.0       3.0
# 2               5.0        1.0           1.0                  92.0       1.0
# 3               4.0        1.0           1.0                   NaN       2.0
# 4               2.0        1.0           1.0                  40.0       0.0
# ...             ...        ...           ...                   ...       ...
# 74104           2.0        1.0           1.0                 100.0       1.0
# 74107           4.0        2.0           1.0                  93.0       2.0
# 74108           5.0        1.0           1.0                  94.0       2.0
# 74109           2.0        1.0           1.0                   NaN       0.0
# 74110           4.0        1.0           0.0                  96.0       1.0
#
#        beds  log_price  room_type_Private room  room_type_Shared room  \
# 0       1.0   5.010635                     0.0                    0.0
# 1       3.0   5.129899                     0.0                    0.0
# 2       3.0   4.976734                     0.0                    0.0
# 3       2.0   6.620073                     0.0                    0.0
# 4       1.0   4.744932                     0.0                    0.0
# ...     ...        ...                     ...                    ...
# 74104   1.0   4.356709                     0.0                    0.0
# 74107   4.0   5.043425                     0.0                    0.0
# 74108   2.0   5.220356                     0.0                    0.0
# 74109   2.0   5.273000                     0.0                    0.0
# 74110   2.0   4.852030                     0.0                    0.0
#
#        cancellation_policy_moderate  cancellation_policy_strict  \
# 0                               0.0                         1.0
# 1                               0.0                         1.0
# 2                               1.0                         0.0
# 3                               0.0                         0.0
# 4                               1.0                         0.0
# ...                             ...                         ...
# 74104                           0.0                         1.0
# 74107                           1.0                         0.0
# 74108                           1.0                         0.0
# 74109                           0.0                         1.0
# 74110                           1.0                         0.0
#
#        instant_bookable_t
# 0                     0.0
# 1                     1.0
# 2                     1.0
# 3                     0.0
# 4                     1.0
# ...                   ...
# 74104                 0.0
# 74107                 0.0
# 74108                 1.0
# 74109                 1.0
# 74110                 0.0
#
# [54117 rows x 12 columns]

# %% [markdown]
# # Null Value Treatment

# %%
df_mean = df_2

# %%
for column in df_mean.columns:


    if df_mean[column].dtype != 'object':


        mean = df_mean[column].mean()


        df_mean[column] = df_mean[column].fillna(mean)

# %%
df_mean
# Out:
#        accommodates  bathrooms  cleaning_fee  review_scores_rating  bedrooms  \
# 0               3.0        1.0           1.0            100.000000       1.0
# 1               7.0        1.0           1.0             93.000000       3.0
# 2               5.0        1.0           1.0             92.000000       1.0
# 3               4.0        1.0           1.0             93.202041       2.0
# 4               2.0        1.0           1.0             40.000000       0.0
# ...             ...        ...           ...                   ...       ...
# 74104           2.0        1.0           1.0            100.000000       1.0
# 74107           4.0        2.0           1.0             93.000000       2.0
# 74108           5.0        1.0           1.0             94.000000       2.0
# 74109           2.0        1.0           1.0             93.202041       0.0
# 74110           4.0        1.0           0.0             96.000000       1.0
#
#        beds  log_price  room_type_Private room  room_type_Shared room  \
# 0       1.0   5.010635                     0.0                    0.0
# 1       3.0   5.129899                     0.0                    0.0
# 2       3.0   4.976734                     0.0                    0.0
# 3       2.0   6.620073                     0.0                    0.0
# 4       1.0   4.744932                     0.0                    0.0
# ...     ...        ...                     ...                    ...
# 74104   1.0   4.356709                     0.0                    0.0
# 74107   4.0   5.043425                     0.0                    0.0
# 74108   2.0   5.220356                     0.0                    0.0
# 74109   2.0   5.273000                     0.0                    0.0
# 74110   2.0   4.852030                     0.0                    0.0
#
#        cancellation_policy_moderate  cancellation_policy_strict  \
# 0                               0.0                         1.0
# 1                               0.0                         1.0
# 2                               1.0                         0.0
# 3                               0.0                         0.0
# 4                               1.0                         0.0
# ...                             ...                         ...
# 74104                           0.0                         1.0
# 74107                           1.0                         0.0
# 74108                           1.0                         0.0
# 74109                           0.0                         1.0
# 74110                           1.0                         0.0
#
#        instant_bookable_t
# 0                     0.0
# 1                     1.0
# 2                     1.0
# 3                     0.0
# 4                     1.0
# ...                   ...
# 74104                 0.0
# 74107                 0.0
# 74108                 1.0
# 74109                 1.0
# 74110                 0.0
#
# [54117 rows x 12 columns]

# %%
df_med = df_2.copy()

# %%
for column in df_med.columns:

    if df_med[column].dtype != 'object':

        median = df_med[column].median()

        df_med[column] = df_med[column].fillna(median)

# %%
df_med
# Out:
#        accommodates  bathrooms  cleaning_fee  review_scores_rating  bedrooms  \
# 0               3.0        1.0           1.0            100.000000       1.0
# 1               7.0        1.0           1.0             93.000000       3.0
# 2               5.0        1.0           1.0             92.000000       1.0
# 3               4.0        1.0           1.0             93.202041       2.0
# 4               2.0        1.0           1.0             40.000000       0.0
# ...             ...        ...           ...                   ...       ...
# 74104           2.0        1.0           1.0            100.000000       1.0
# 74107           4.0        2.0           1.0             93.000000       2.0
# 74108           5.0        1.0           1.0             94.000000       2.0
# 74109           2.0        1.0           1.0             93.202041       0.0
# 74110           4.0        1.0           0.0             96.000000       1.0
#
#        beds  log_price  room_type_Private room  room_type_Shared room  \
# 0       1.0   5.010635                     0.0                    0.0
# 1       3.0   5.129899                     0.0                    0.0
# 2       3.0   4.976734                     0.0                    0.0
# 3       2.0   6.620073                     0.0                    0.0
# 4       1.0   4.744932                     0.0                    0.0
# ...     ...        ...                     ...                    ...
# 74104   1.0   4.356709                     0.0                    0.0
# 74107   4.0   5.043425                     0.0                    0.0
# 74108   2.0   5.220356                     0.0                    0.0
# 74109   2.0   5.273000                     0.0                    0.0
# 74110   2.0   4.852030                     0.0                    0.0
#
#        cancellation_policy_moderate  cancellation_policy_strict  \
# 0                               0.0                         1.0
# 1                               0.0                         1.0
# 2                               1.0                         0.0
# 3                               0.0                         0.0
# 4                               1.0                         0.0
# ...                             ...                         ...
# 74104                           0.0                         1.0
# 74107                           1.0                         0.0
# 74108                           1.0                         0.0
# 74109                           0.0                         1.0
# 74110                           1.0                         0.0
#
#        instant_bookable_t
# 0                     0.0
# 1                     1.0
# 2                     1.0
# 3                     0.0
# 4                     1.0
# ...                   ...
# 74104                 0.0
# 74107                 0.0
# 74108                 1.0
# 74109                 1.0
# 74110                 0.0
#
# [54117 rows x 12 columns]

# %%
df_med.isnull().sum()
# Out:
# accommodates                    0
# bathrooms                       0
# cleaning_fee                    0
# review_scores_rating            0
# bedrooms                        0
# beds                            0
# log_price                       0
# room_type_Private room          0
# room_type_Shared room           0
# cancellation_policy_moderate    0
# cancellation_policy_strict      0
# instant_bookable_t              0
# dtype: int64

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=5)
df_imputed=imputer.fit_transform(df_2)
df_knn = pd.DataFrame(data = df_imputed,columns=df_2.columns)

# %%
df_knn
# Out:
#        accommodates  bathrooms  cleaning_fee  review_scores_rating  bedrooms  \
# 0               3.0        1.0           1.0            100.000000       1.0
# 1               7.0        1.0           1.0             93.000000       3.0
# 2               5.0        1.0           1.0             92.000000       1.0
# 3               4.0        1.0           1.0             93.202041       2.0
# 4               2.0        1.0           1.0             40.000000       0.0
# ...             ...        ...           ...                   ...       ...
# 54112           2.0        1.0           1.0            100.000000       1.0
# 54113           4.0        2.0           1.0             93.000000       2.0
# 54114           5.0        1.0           1.0             94.000000       2.0
# 54115           2.0        1.0           1.0             93.202041       0.0
# 54116           4.0        1.0           0.0             96.000000       1.0
#
#        beds  log_price  room_type_Private room  room_type_Shared room  \
# 0       1.0   5.010635                     0.0                    0.0
# 1       3.0   5.129899                     0.0                    0.0
# 2       3.0   4.976734                     0.0                    0.0
# 3       2.0   6.620073                     0.0                    0.0
# 4       1.0   4.744932                     0.0                    0.0
# ...     ...        ...                     ...                    ...
# 54112   1.0   4.356709                     0.0                    0.0
# 54113   4.0   5.043425                     0.0                    0.0
# 54114   2.0   5.220356                     0.0                    0.0
# 54115   2.0   5.273000                     0.0                    0.0
# 54116   2.0   4.852030                     0.0                    0.0
#
#        cancellation_policy_moderate  cancellation_policy_strict  \
# 0                               0.0                         1.0
# 1                               0.0                         1.0
# 2                               1.0                         0.0
# 3                               0.0                         0.0
# 4                               1.0                         0.0
# ...                             ...                         ...
# 54112                           0.0                         1.0
# 54113                           1.0                         0.0
# 54114                           1.0                         0.0
# 54115                           0.0                         1.0
# 54116                           1.0                         0.0
#
#        instant_bookable_t
# 0                     0.0
# 1                     1.0
# 2                     1.0
# 3                     0.0
# 4                     1.0
# ...                   ...
# 54112                 0.0
# 54113                 0.0
# 54114                 1.0
# 54115                 1.0
# 54116                 0.0
#
# [54117 rows x 12 columns]

# %% [markdown]
# # Outlier Treatment

# %%
cont=df_knn.dtypes[(df_knn.dtypes!='uint8') & (df_knn.dtypes!='bool')].index
plt.figure(figsize=(10,10))
df_knn[cont].boxplot(vert=False)
plt.title('With Outliers',fontsize=16)
plt.show()

# %%
def remove_outlier(col):

    sorted(col)

    Q1,Q3=np.percentile(col,[25,75])

    IQR=Q3-Q1

    lower_range= Q1-(1.5 * IQR)

    upper_range= Q3+(1.5 * IQR)

    return lower_range, upper_range

# %%
remove_outlier(df_mean['review_scores_rating'])
# Out:
# (83.0, 107.0)

# %%
df_mean_out = df_mean.copy()
df_med_out = df_med.copy()
df_knn_out = df_knn.copy()

# %%
for column in df_mean_out.columns:

    lr,ur=remove_outlier(df_mean_out[column])


    df_mean_out[column]=np.where(df_mean_out[column]>ur,ur,df_mean_out[column])      ##outlier collapse on upper limit


    df_mean_out[column]=np.where(df_mean_out[column]<lr,lr,df_mean_out[column])      ##outlier collaspse on lower limit

# %%
plt.figure(figsize=(10,10))
df_knn_out.boxplot(vert=False)
plt.title('Without Outliers',fontsize=16)
plt.show()

# %%
for column in df_med_out.columns:

    lr,ur=remove_outlier(df_med_out[column])


    df_med_out[column]=np.where(df_med_out[column]>ur,ur,df_med_out[column])


    df_med_out[column]=np.where(df_med_out[column]<lr,lr,df_med_out[column])

# %%
for column in df_knn_out.columns:

    lr,ur=remove_outlier(df_knn_out[column])


    df_knn_out[column]=np.where(df_knn_out[column]>ur,ur,df_knn_out[column])


    df_knn_out[column]=np.where(df_knn_out[column]<lr,lr,df_knn_out[column])

# %% [markdown]
# ## Data Distribution

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df_mean.corr(),annot=True)

plt.show
##good corelation - 0.7,0.8
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Train-Test-Split

# %%
X = df_mean_out.drop('log_price', axis=1)     #x is independent variable

# Copy target into the y dataframe.
y = df_mean_out[['log_price']] #y is dependent variable seperate

# %%
X.head()
# Out:
#    accommodates  bathrooms  cleaning_fee  review_scores_rating  bedrooms  \
# 0           3.0        1.0           1.0            100.000000       1.0
# 1           7.0        1.0           1.0             93.000000       3.0
# 2           5.0        1.0           1.0             92.000000       1.0
# 3           4.0        1.0           1.0             93.202041       2.0
# 4           2.0        1.0           1.0             83.000000       0.0
#
#    beds  room_type_Private room  room_type_Shared room  \
# 0   1.0                     0.0                    0.0
# 1   3.0                     0.0                    0.0
# 2   3.0                     0.0                    0.0
# 3   2.0                     0.0                    0.0
# 4   1.0                     0.0                    0.0
#
#    cancellation_policy_moderate  cancellation_policy_strict  \
# 0                           0.0                         1.0
# 1                           0.0                         1.0
# 2                           1.0                         0.0
# 3                           0.0                         0.0
# 4                           1.0                         0.0
#
#    instant_bookable_t
# 0                 0.0
# 1                 1.0
# 2                 1.0
# 3                 0.0
# 4                 1.0

# %%
y.head()
# Out:
#    log_price
# 0   5.010635
# 1   5.129899
# 2   4.976734
# 3   6.620073
# 4   4.744932

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3 , random_state=1)

# %% [markdown]
# # Linear Regression Model

# %%
regression_model = LinearRegression()

regression_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regression_model.score(X_train, y_train)
# Out:
# 0.4453405404485786

# %% [markdown]
# ## Mean - Outlier not treated

# %%
X = df_mean.drop('log_price', axis=1)

# Copy target into the y dataframe.
y = df_mean[['log_price']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3 , random_state=1)

# %%
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regression_model.score(X_train, y_train)
# Out:
# 0.4245857731261171

# %% [markdown]
# ## Med - Outler Treated

# %%
X = df_med_out.drop('log_price', axis=1)

# Copy target into the y dataframe.
y = df_med_out[['log_price']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3 , random_state=1)

regression_model.fit(X_train, y_train)

regression_model.score(X_train, y_train)
# Out:
# 0.4453405404485786

# %%
X = df_med.drop('log_price', axis=1)

# Copy target into the y dataframe.
y = df_med[['log_price']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3 , random_state=1)

regression_model.fit(X_train, y_train)

regression_model.score(X_train, y_train)
# Out:
# 0.5026453886994027

# %% [markdown]
# KNN - outler treated

# %%
X = df_knn_out.drop('log_price', axis=1)

# Copy target into the y dataframe.
y = df_knn_out[['log_price']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3 , random_state=1)

regression_model.fit(X_train, y_train)

regression_model.score(X_train, y_train)
# Out:
# 0.4453405404485786

# %%
X = df_knn.drop('log_price', axis=1)

# Copy target into the y dataframe.
y = df_knn[['log_price']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3 , random_state=1)

regression_model.fit(X_train, y_train)

regression_model.score(X_train, y_train)
# Out:
# 0.5026453886994027

# %%
df_2
# Out:
#        accommodates  bathrooms  cleaning_fee  review_scores_rating  bedrooms  \
# 0               3.0        1.0           1.0            100.000000       1.0
# 1               7.0        1.0           1.0             93.000000       3.0
# 2               5.0        1.0           1.0             92.000000       1.0
# 3               4.0        1.0           1.0             93.202041       2.0
# 4               2.0        1.0           1.0             40.000000       0.0
# ...             ...        ...           ...                   ...       ...
# 74104           2.0        1.0           1.0            100.000000       1.0
# 74107           4.0        2.0           1.0             93.000000       2.0
# 74108           5.0        1.0           1.0             94.000000       2.0
# 74109           2.0        1.0           1.0             93.202041       0.0
# 74110           4.0        1.0           0.0             96.000000       1.0
#
#        beds  log_price  room_type_Private room  room_type_Shared room  \
# 0       1.0   5.010635                     0.0                    0.0
# 1       3.0   5.129899                     0.0                    0.0
# 2       3.0   4.976734                     0.0                    0.0
# 3       2.0   6.620073                     0.0                    0.0
# 4       1.0   4.744932                     0.0                    0.0
# ...     ...        ...                     ...                    ...
# 74104   1.0   4.356709                     0.0                    0.0
# 74107   4.0   5.043425                     0.0                    0.0
# 74108   2.0   5.220356                     0.0                    0.0
# 74109   2.0   5.273000                     0.0                    0.0
# 74110   2.0   4.852030                     0.0                    0.0
#
#        cancellation_policy_moderate  cancellation_policy_strict  \
# 0                               0.0                         1.0
# 1                               0.0                         1.0
# 2                               1.0                         0.0
# 3                               0.0                         0.0
# 4                               1.0                         0.0
# ...                             ...                         ...
# 74104                           0.0                         1.0
# 74107                           1.0                         0.0
# 74108                           1.0                         0.0
# 74109                           0.0                         1.0
# 74110                           1.0                         0.0
#
#        instant_bookable_t
# 0                     0.0
# 1                     1.0
# 2                     1.0
# 3                     0.0
# 4                     1.0
# ...                   ...
# 74104                 0.0
# 74107                 0.0
# 74108                 1.0
# 74109                 1.0
# 74110                 0.0
#
# [54117 rows x 12 columns]

# %%
data_train = pd.concat([X_train, y_train], axis=1)
data_test=pd.concat([X_test,y_test],axis=1)
data_train.head()           ## stats model
# Out:
#        accommodates  bathrooms  cleaning_fee  review_scores_rating  bedrooms  \
# 25136           7.0        1.0           0.0            100.000000       1.0
# 6288            1.0        2.0           0.0             99.000000       1.0
# 36561           2.0        1.0           0.0             80.000000       1.0
# 2034           16.0        1.0           1.0            100.000000       0.0
# 21668           3.0        1.0           0.0             93.202041       1.0
#
#        beds  room_type_Private room  room_type_Shared room  \
# 25136   3.0                     0.0                    0.0
# 6288    1.0                     1.0                    0.0
# 36561   1.0                     0.0                    0.0
# 2034    1.0                     0.0                    0.0
# 21668   1.0                     0.0                    1.0
#
#        cancellation_policy_moderate  cancellation_policy_strict  \
# 25136                           0.0                         0.0
# 6288                            0.0                         1.0
# 36561                           1.0                         0.0
# 2034                            0.0                         1.0
# 21668                           0.0                         1.0
#
#        instant_bookable_t  log_price
# 25136                 0.0   4.709530
# 6288                  1.0   3.806662
# 36561                 0.0   4.844187
# 2034                  0.0   6.396930
# 21668                 1.0   4.499810

# %%
expr= 'log_price ~ accommodates + bathrooms + instant_bookable_t+review_scores_rating +bedrooms + beds + room_type_Private room + room_type_shared room  + cancellation_policy_moderate + cancellation_policy_strict + cleaning_fee'
## expresion is a model

# %%
import statsmodels.formula.api as smf   ## importing model
lm1 = smf.ols(formula= expr, data = data_train).fit()
lm1.params
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-68-943c14b1f4c4>", line 2, in <cell line: 0>
#     lm1 = smf.ols(formula= expr, data = data_train).fit()
#
#   File "/usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py", line 203, in from_formula
#     tmp = handle_formula_data(data, None, formula, depth=eval_env,
#
#   File "/usr/local/lib/python3.11/dist-packages/statsmodels/formula/formulatools.py", line 63, in handle_formula_data
#     result = dmatrices(formula, Y, depth, return_type='dataframe',
#
#   File "/usr/local/lib/python3.11/dist-packages/patsy/highlevel.py", line 319, in dmatrices
#     (lhs, rhs) = _do_highlevel_design(
#
#   File "/usr/local/lib/python3.11/dist-packages/patsy/highlevel.py", line 164, in _do_highlevel_design
#     design_infos = _try_incr_builders(
#
#   File "/usr/local/lib/python3.11/dist-packages/patsy/highlevel.py", line 56, in _try_incr_builders
#     return design_matrix_builders(
#
#   File "/usr/local/lib/python3.11/dist-packages/patsy/build.py", line 743, in design_matrix_builders
#     factor_states = _factors_memorize(all_factors, data_iter_maker, eval_env)
#
#   File "/usr/local/lib/python3.11/dist-packages/patsy/build.py", line 393, in _factors_memorize
#     which_pass = factor.memorize_passes_needed(state, eval_env)
#
#   File "/usr/local/lib/python3.11/dist-packages/patsy/eval.py", line 504, in memorize_passes_needed
#     subset_names = [name for name in ast_names(self.code) if name in env_namespace]
#
#   File "/usr/local/lib/python3.11/dist-packages/patsy/eval.py", line 504, in <listcomp>
#     subset_names = [name for name in ast_names(self.code) if name in env_namespace]
#
#   File "/usr/local/lib/python3.11/dist-packages/patsy/eval.py", line 111, in ast_names
#     for node in ast.walk(ast.parse(code)):
#
#   File "/usr/lib/python3.11/ast.py", line 50, in parse
#     return compile(source, filename, mode, flags,
#
#   File "<unknown>", line 1
#     room_type_shared room
#                      ^
# SyntaxError: invalid syntax

# %%
for idx, col_name in enumerate(X_train.columns):
    print("The coefficient for {} is {}".format(col_name, regression_model.coef_[0][idx]))
## summary of equations
# Out:
# The coefficient for accommodates is 0.07462894458497231
# The coefficient for bathrooms is 0.15619410944340772
# The coefficient for cleaning_fee is -0.0903974044904626
# The coefficient for review_scores_rating is 0.006028806002826001
# The coefficient for bedrooms is 0.15461656719233013
# The coefficient for beds is -0.05025112925265787
# The coefficient for room_type_Private room is -0.649056771108377
# The coefficient for room_type_Shared room is -1.1023194166369084
# The coefficient for cancellation_policy_moderate is -0.06647819487045392
# The coefficient for cancellation_policy_strict is -0.014290927638931219
# The coefficient for instant_bookable_t is -0.057925496162736324

# %%
intercept = regression_model.intercept_[0]

print("The intercept for our model is {}".format(intercept))
# Out:
# The intercept for our model is 4.0890342423916115
